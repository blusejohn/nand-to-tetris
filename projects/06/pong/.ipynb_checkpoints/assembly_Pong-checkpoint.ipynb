# %%
symbols = {
    'R0': 0,
    'R1': 1,
    'R2': 2,
    'R3': 3,
    'R4': 4,
    'R5': 5,
    'R6': 6,
    'R7': 7,
    'R8': 8,
    'R9': 9,
    'R1O': 10,
    'R11': 11,
    'R12': 12,
    'R13': 13,
    'R14': 14,
    'R15': 15,
    'SCREEN': 16384,
    'KBD': 24576,
    'SP': 0,
    'LCL': 1,
    'ARG': 2,
    'THIS': 3,
    'THAT': 4
}

start_address = 16

def convert_comp_to_bin(comp):
    compTable = {
        '0': '0101010',
        '1': '0111111',
        '-1':'0111010',
        'D':'0001100',
        'A':'0110000',
        'M':'1110000',
        '!D':'0001101',
        '!A':'0110001',
        '!M':'1110001',
        '-D':'0001111',
        '-A':'0110011',
        '-M':'1110011',
        'D+1':'0011111',
        'A+1':'0110111',
        'M+1':'1110111',
        'D-1':'0001110',
        'A-1':'0110010',
        'M-1':'1110010',
        'D+A':'0000010',
        'D+M':'1000010',
        'D-A':'0010011',
        'D-M':'1010011',
        'A-D':'0000111',
        'M-D':'1000111',
        'D&A':'0000000',
        'D&M':'1000000',
        'D|A':'0010101',
        'D|M':'1010101',
    }
    return compTable[comp]

def convert_dest_to_bin(dest):
    if not dest:
        return '000'
    destTable = {
        'M':'001',
        'D':'010',
        'MD':'011',
        'A':'100',
        'AM':'101',
        'AD':'110',
        'AMD':'111',
    }
    return destTable[dest]

def convert_jump_to_bin(jump):
    if not jump:
        return '000'
    jumpTable = {
        'JGT':'001',
        'JEQ':'010',
        'JGE':'011',
        'JLT':'100',
        'JNE':'101',
        'JLE':'110',
        'JMP':'111',
    }
    return jumpTable[jump]

def number_to_16bit_bin(number):
    return "{0:016b}".format(number)

def add_symbol_to_symbolTable(symbols,word,index):
    symbols.update({word: index})
    
def parse_symbol(symbol):
    global start_address
    if symbol not in symbols:
        add_symbol_to_symbolTable(symbols,symbol,next_address)
        start_address += 1
    return symbols[symbol]
    

def parse_into_c_instruction(instruction):
    dest = None;
    jump = None;
    
    if '=' in instruction:
        [dest,instruction] = instruction.split('=')
    if ';' in instruction:
        [comp,jump] = instruction.split(';')
    else:
        comp = instruction
    
    result = '111'
    result+=convert_comp_to_bin(comp)
    result+=convert_dest_to_bin(dest)
    result+=convert_jump_to_bin(jump)
    return result
        
    
def parse_into_a_instruction(instruction):
    address = instruction[1:]
    try:
        return number_to_16bit_bin(int(address))
    except ValueError:
        return number_to_16bit_bin(parse_symbol(address))
        
    
def input_preprcess(inputFile):
    lines = inputFile.readlines()
    parse_result = []
    ##Take away '//' and empty line
    for line in lines:
        line = line.replace(" ", "")
        if(line == '\n'):
            continue
        elif(line[0]=='/'):
            continue
        line = line.replace("\n", "")
        line = line.split('//', 1)[0]
        parse_result.append(line)
    return parse_result

# %%
inputFile = open('Pong.asm', 'r')


#process the data to remove // and space
files = input_preprcess(inputFile)

#Round 1 to replace Label Symbols
for line in files:
    if ( line[0]=='('and line[len(line) - 1] == ')' ):
        print(line)
        index = files.index(line)
#         files.remove(line)
#         line = line.replace('(', "").replace(')',"")
#         symbols[line] = index
# Out:
# (END_EQ)
# (END_GT)
# (END_LT)
# (RET_ADDRESS_CALL0)
# (RET_ADDRESS_CALL1)
# (RET_ADDRESS_CALL2)
# (ball.dispose)
# (RET_ADDRESS_CALL3)
# (ball.show)
# (RET_ADDRESS_CALL4)
# (RET_ADDRESS_CALL5)
# (ball.hide)
# (RET_ADDRESS_CALL6)
# (RET_ADDRESS_CALL7)
# (ball.draw)
# (RET_ADDRESS_CALL8)
# (ball.getleft)
# (ball.getright)
# (ball.setdestination)
# (LOOP_ball.setdestination)
# (RET_ADDRESS_CALL9)
# (RET_ADDRESS_CALL10)
# (RET_ADDRESS_LT0)
# (ball.setdestination$if_true0)
# (RET_ADDRESS_LT1)
# (RET_ADDRESS_LT2)
# (ball.setdestination$if_false0)
# (RET_ADDRESS_LT3)
# (RET_ADDRESS_LT4)
# (ball.setdestination$if_end0)
# (RET_ADDRESS_CALL11)
# (RET_ADDRESS_CALL12)
# (RET_ADDRESS_CALL13)
# (ball.move)
# (RET_ADDRESS_CALL14)
# (RET_ADDRESS_LT5)
# (ball.move$if_true0)
# (ball.move$if_false0)
# (ball.move$if_true1)
# (ball.move$if_true2)
# (ball.move$if_false2)
# (ball.move$if_end2)
# (ball.move$if_false1)
# (ball.move$if_true3)
# (ball.move$if_false3)
# (ball.move$if_end3)
# (ball.move$if_end0)
# (ball.move$if_true4)
# (ball.move$if_true5)
# (ball.move$if_false5)
# (ball.move$if_end5)
# (ball.move$if_false4)
# (ball.move$if_true6)
# (ball.move$if_false6)
# (ball.move$if_end6)
# (RET_ADDRESS_GT0)
# (ball.move$if_true7)
# (ball.move$if_false7)
# (RET_ADDRESS_LT6)
# (ball.move$if_true8)
# (ball.move$if_false8)
# (RET_ADDRESS_GT1)
# (ball.move$if_true9)
# (ball.move$if_false9)
# (RET_ADDRESS_LT7)
# (ball.move$if_true10)
# (ball.move$if_false10)
# (RET_ADDRESS_CALL15)
# (ball.bounce)
# (LOOP_ball.bounce)
# (RET_ADDRESS_CALL16)
# (RET_ADDRESS_CALL17)
# (RET_ADDRESS_EQ0)
# (ball.bounce$if_true0)
# (ball.bounce$if_false0)
# (RET_ADDRESS_LT8)
# (RET_ADDRESS_EQ1)
# (RET_ADDRESS_LT9)
# (RET_ADDRESS_EQ2)
# (ball.bounce$if_true1)
# (ball.bounce$if_false1)
# (ball.bounce$if_end1)
# (RET_ADDRESS_EQ3)
# (ball.bounce$if_true2)
# (RET_ADDRESS_CALL18)
# (RET_ADDRESS_CALL19)
# (RET_ADDRESS_CALL20)
# (ball.bounce$if_false2)
# (RET_ADDRESS_EQ4)
# (ball.bounce$if_true3)
# (RET_ADDRESS_CALL21)
# (RET_ADDRESS_CALL22)
# (RET_ADDRESS_CALL23)
# (ball.bounce$if_false3)
# (RET_ADDRESS_EQ5)
# (ball.bounce$if_true4)
# (RET_ADDRESS_CALL24)
# (RET_ADDRESS_CALL25)
# (RET_ADDRESS_CALL26)
# (ball.bounce$if_false4)
# (RET_ADDRESS_CALL27)
# (RET_ADDRESS_CALL28)
# (RET_ADDRESS_CALL29)
# (ball.bounce$if_end4)
# (ball.bounce$if_end2)
# (RET_ADDRESS_CALL30)
# (bat.new)
# (RET_ADDRESS_CALL31)
# (RET_ADDRESS_CALL32)
# (bat.dispose)
# (RET_ADDRESS_CALL33)
# (bat.show)
# (RET_ADDRESS_CALL34)
# (RET_ADDRESS_CALL35)
# (bat.hide)
# (RET_ADDRESS_CALL36)
# (RET_ADDRESS_CALL37)
# (bat.draw)
# (RET_ADDRESS_CALL38)
# (bat.setdirection)
# (bat.getleft)
# (bat.getright)
# (bat.setwidth)
# (RET_ADDRESS_CALL39)
# (RET_ADDRESS_CALL40)
# (bat.move)
# (RET_ADDRESS_EQ6)
# (bat.move$if_true0)
# (RET_ADDRESS_LT10)
# (bat.move$if_true1)
# (bat.move$if_false1)
# (RET_ADDRESS_CALL41)
# (RET_ADDRESS_CALL42)
# (RET_ADDRESS_CALL43)
# (RET_ADDRESS_CALL44)
# (bat.move$if_false0)
# (RET_ADDRESS_GT2)
# (bat.move$if_true2)
# (bat.move$if_false2)
# (RET_ADDRESS_CALL45)
# (RET_ADDRESS_CALL46)
# (RET_ADDRESS_CALL47)
# (RET_ADDRESS_CALL48)
# (bat.move$if_end0)
# (main.main)
# (RET_ADDRESS_CALL49)
# (RET_ADDRESS_CALL50)
# (RET_ADDRESS_CALL51)
# (RET_ADDRESS_CALL52)
# (ponggame.new)
# (RET_ADDRESS_CALL53)
# (RET_ADDRESS_CALL54)
# (RET_ADDRESS_CALL55)
# (RET_ADDRESS_CALL56)
# (RET_ADDRESS_CALL57)
# (RET_ADDRESS_CALL58)
# (RET_ADDRESS_CALL59)
# (RET_ADDRESS_CALL60)
# (RET_ADDRESS_CALL61)
# (RET_ADDRESS_CALL62)
# (RET_ADDRESS_CALL63)
# (RET_ADDRESS_CALL64)
# (RET_ADDRESS_CALL65)
# (RET_ADDRESS_CALL66)
# (RET_ADDRESS_CALL67)
# (RET_ADDRESS_CALL68)
# (RET_ADDRESS_CALL69)
# (ponggame.dispose)
# (RET_ADDRESS_CALL70)
# (RET_ADDRESS_CALL71)
# (RET_ADDRESS_CALL72)
# (ponggame.newinstance)
# (RET_ADDRESS_CALL73)
# (ponggame.getinstance)
# (ponggame.run)
# (ponggame.run$while_exp0)
# (ponggame.run$while_exp1)
# (RET_ADDRESS_EQ7)
# (RET_ADDRESS_CALL74)
# (RET_ADDRESS_CALL75)
# (RET_ADDRESS_CALL76)
# (ponggame.run$while_end1)
# (RET_ADDRESS_EQ8)
# (ponggame.run$if_true0)
# (RET_ADDRESS_CALL77)
# (ponggame.run$if_false0)
# (RET_ADDRESS_EQ9)
# (ponggame.run$if_true1)
# (RET_ADDRESS_CALL78)
# (ponggame.run$if_false1)
# (RET_ADDRESS_EQ10)
# (ponggame.run$if_true2)
# (ponggame.run$if_false2)
# (ponggame.run$if_end0)
# (RET_ADDRESS_EQ11)
# (RET_ADDRESS_CALL79)
# (RET_ADDRESS_CALL80)
# (RET_ADDRESS_CALL81)
# (ponggame.run$while_end2)
# (ponggame.run$while_end0)
# (ponggame.run$if_true3)
# (RET_ADDRESS_CALL82)
# (RET_ADDRESS_CALL83)
# (RET_ADDRESS_CALL84)
# (RET_ADDRESS_CALL85)
# (RET_ADDRESS_CALL86)
# (RET_ADDRESS_CALL87)
# (RET_ADDRESS_CALL88)
# (RET_ADDRESS_CALL89)
# (RET_ADDRESS_CALL90)
# (RET_ADDRESS_CALL91)
# (RET_ADDRESS_CALL92)
# (RET_ADDRESS_CALL93)
# (ponggame.run$if_false3)
# (ponggame.moveball)
# (LOOP_ponggame.moveball)
# (RET_ADDRESS_CALL94)
# (RET_ADDRESS_GT3)
# (RET_ADDRESS_EQ12)
# (ponggame.moveball$if_true0)
# (RET_ADDRESS_CALL95)
# (RET_ADDRESS_CALL96)
# (RET_ADDRESS_CALL97)
# (RET_ADDRESS_CALL98)
# (RET_ADDRESS_EQ13)
# (ponggame.moveball$if_true1)
# (RET_ADDRESS_GT4)
# (RET_ADDRESS_LT11)
# (ponggame.moveball$if_true2)
# (RET_ADDRESS_LT12)
# (ponggame.moveball$if_true3)
# (ponggame.moveball$if_false3)
# (RET_ADDRESS_GT5)
# (ponggame.moveball$if_true4)
# (ponggame.moveball$if_false4)
# (RET_ADDRESS_CALL99)
# (RET_ADDRESS_CALL100)
# (RET_ADDRESS_CALL101)
# (ponggame.moveball$if_false2)
# (RET_ADDRESS_CALL102)
# (ponggame.moveball$if_false0)
# (array.new)
# (RET_ADDRESS_GT6)
# (array.new$if_true0)
# (RET_ADDRESS_CALL103)
# (array.new$if_false0)
# (RET_ADDRESS_CALL104)
# (array.dispose)
# (RET_ADDRESS_CALL105)
# (keyboard.init)
# (keyboard.keypressed)
# (RET_ADDRESS_CALL106)
# (keyboard.readchar)
# (RET_ADDRESS_CALL107)
# (keyboard.readchar$while_exp0)
# (RET_ADDRESS_EQ14)
# (RET_ADDRESS_GT7)
# (RET_ADDRESS_CALL108)
# (RET_ADDRESS_GT8)
# (keyboard.readchar$if_true0)
# (keyboard.readchar$if_false0)
# (keyboard.readchar$while_end0)
# (RET_ADDRESS_CALL109)
# (RET_ADDRESS_CALL110)
# (RET_ADDRESS_CALL111)
# (keyboard.readline)
# (LOOP_keyboard.readline)
# (RET_ADDRESS_CALL112)
# (RET_ADDRESS_CALL113)
# (RET_ADDRESS_CALL114)
# (RET_ADDRESS_CALL115)
# (keyboard.readline$while_exp0)
# (RET_ADDRESS_CALL116)
# (RET_ADDRESS_EQ15)
# (keyboard.readline$if_true0)
# (RET_ADDRESS_EQ16)
# (keyboard.readline$if_true1)
# (RET_ADDRESS_CALL117)
# (keyboard.readline$if_false1)
# (RET_ADDRESS_CALL118)
# (keyboard.readline$if_end1)
# (keyboard.readline$while_end0)
# (keyboard.readint)
# (RET_ADDRESS_CALL119)
# (RET_ADDRESS_CALL120)
# (RET_ADDRESS_CALL121)
# (math.init)
# (RET_ADDRESS_CALL122)
# (RET_ADDRESS_CALL123)
# (math.init$while_exp0)
# (RET_ADDRESS_LT13)
# (math.init$while_end0)
# (math.abs)
# (RET_ADDRESS_LT14)
# (math.abs$if_true0)
# (math.abs$if_false0)
# (math.multiply)
# (LOOP_math.multiply)
# (RET_ADDRESS_LT15)
# (RET_ADDRESS_GT9)
# (RET_ADDRESS_GT10)
# (RET_ADDRESS_LT16)
# (RET_ADDRESS_CALL124)
# (RET_ADDRESS_CALL125)
# (RET_ADDRESS_LT17)
# (math.multiply$if_true0)
# (math.multiply$if_false0)
# (RET_ADDRESS_LT18)
# (RET_ADDRESS_GT11)
# (math.multiply$if_true1)
# (math.multiply$if_false1)
# (math.multiply$while_end0)
# (math.multiply$if_true2)
# (math.multiply$if_false2)
# (math.divide)
# (LOOP_math.divide)
# (RET_ADDRESS_EQ17)
# (math.divide$if_true0)
# (RET_ADDRESS_CALL126)
# (math.divide$if_false0)
# (RET_ADDRESS_LT19)
# (RET_ADDRESS_GT12)
# (RET_ADDRESS_GT13)
# (RET_ADDRESS_LT20)
# (RET_ADDRESS_CALL127)
# (RET_ADDRESS_CALL128)
# (math.divide$while_exp0)
# (RET_ADDRESS_LT21)
# (math.divide$if_true1)
# (RET_ADDRESS_GT14)
# (math.divide$if_true2)
# (math.divide$if_false2)
# (math.divide$while_end0)
# (RET_ADDRESS_GT15)
# (RET_ADDRESS_GT16)
# (math.divide$if_true3)
# (math.divide$if_false3)
# (math.divide$while_end1)
# (math.divide$if_true4)
# (math.divide$if_false4)
# (math.sqrt)
# (LOOP_math.sqrt)
# (RET_ADDRESS_LT22)
# (math.sqrt$if_true0)
# (RET_ADDRESS_CALL129)
# (math.sqrt$if_false0)
# (math.sqrt$while_exp0)
# (RET_ADDRESS_GT17)
# (RET_ADDRESS_CALL130)
# (RET_ADDRESS_GT18)
# (RET_ADDRESS_LT23)
# (math.sqrt$if_true1)
# (math.sqrt$if_false1)
# (math.sqrt$while_end0)
# (math.max)
# (RET_ADDRESS_GT19)
# (math.max$if_true0)
# (math.max$if_false0)
# (math.min)
# (RET_ADDRESS_LT24)
# (math.min$if_true0)
# (math.min$if_false0)
# (memory.init)
# (memory.peek)
# (memory.poke)
# (memory.alloc)
# (RET_ADDRESS_LT25)
# (memory.alloc$if_true0)
# (RET_ADDRESS_CALL131)
# (memory.alloc$if_false0)
# (memory.alloc$while_exp0)
# (RET_ADDRESS_LT26)
# (memory.alloc$while_end0)
# (RET_ADDRESS_GT20)
# (memory.alloc$if_true1)
# (RET_ADDRESS_CALL132)
# (memory.alloc$if_false1)
# (RET_ADDRESS_GT21)
# (memory.alloc$if_true2)
# (RET_ADDRESS_EQ18)
# (memory.alloc$if_true3)
# (memory.alloc$if_false3)
# (memory.alloc$if_end3)
# (memory.alloc$if_false2)
# (memory.dealloc)
# (RET_ADDRESS_EQ19)
# (memory.dealloc$if_true0)
# (memory.dealloc$if_false0)
# (RET_ADDRESS_EQ20)
# (memory.dealloc$if_true1)
# (memory.dealloc$if_false1)
# (memory.dealloc$if_end1)
# (output.init)
# (RET_ADDRESS_CALL133)
# (RET_ADDRESS_CALL134)
# (RET_ADDRESS_CALL135)
# (output.initmap)
# (RET_ADDRESS_CALL136)
# (RET_ADDRESS_CALL137)
# (RET_ADDRESS_CALL138)
# (RET_ADDRESS_CALL139)
# (RET_ADDRESS_CALL140)
# (RET_ADDRESS_CALL141)
# (RET_ADDRESS_CALL142)
# (RET_ADDRESS_CALL143)
# (RET_ADDRESS_CALL144)
# (RET_ADDRESS_CALL145)
# (RET_ADDRESS_CALL146)
# (RET_ADDRESS_CALL147)
# (RET_ADDRESS_CALL148)
# (RET_ADDRESS_CALL149)
# (RET_ADDRESS_CALL150)
# (RET_ADDRESS_CALL151)
# (RET_ADDRESS_CALL152)
# (RET_ADDRESS_CALL153)
# (RET_ADDRESS_CALL154)
# (RET_ADDRESS_CALL155)
# (RET_ADDRESS_CALL156)
# (RET_ADDRESS_CALL157)
# (RET_ADDRESS_CALL158)
# (RET_ADDRESS_CALL159)
# (RET_ADDRESS_CALL160)
# (RET_ADDRESS_CALL161)
# (RET_ADDRESS_CALL162)
# (RET_ADDRESS_CALL163)
# (RET_ADDRESS_CALL164)
# (RET_ADDRESS_CALL165)
# (RET_ADDRESS_CALL166)
# (RET_ADDRESS_CALL167)
# (RET_ADDRESS_CALL168)
# (RET_ADDRESS_CALL169)
# (RET_ADDRESS_CALL170)
# (RET_ADDRESS_CALL171)
# (RET_ADDRESS_CALL172)
# (RET_ADDRESS_CALL173)
# (RET_ADDRESS_CALL174)
# (RET_ADDRESS_CALL175)
# (RET_ADDRESS_CALL176)
# (RET_ADDRESS_CALL177)
# (RET_ADDRESS_CALL178)
# (RET_ADDRESS_CALL179)
# (RET_ADDRESS_CALL180)
# (RET_ADDRESS_CALL181)
# (RET_ADDRESS_CALL182)
# (RET_ADDRESS_CALL183)
# (RET_ADDRESS_CALL184)
# (RET_ADDRESS_CALL185)
# (RET_ADDRESS_CALL186)
# (RET_ADDRESS_CALL187)
# (RET_ADDRESS_CALL188)
# (RET_ADDRESS_CALL189)
# (RET_ADDRESS_CALL190)
# (RET_ADDRESS_CALL191)
# (RET_ADDRESS_CALL192)
# (RET_ADDRESS_CALL193)
# (RET_ADDRESS_CALL194)
# (RET_ADDRESS_CALL195)
# (RET_ADDRESS_CALL196)
# (RET_ADDRESS_CALL197)
# (RET_ADDRESS_CALL198)
# (RET_ADDRESS_CALL199)
# (RET_ADDRESS_CALL200)
# (RET_ADDRESS_CALL201)
# (RET_ADDRESS_CALL202)
# (RET_ADDRESS_CALL203)
# (RET_ADDRESS_CALL204)
# (RET_ADDRESS_CALL205)
# (RET_ADDRESS_CALL206)
# (RET_ADDRESS_CALL207)
# (RET_ADDRESS_CALL208)
# (RET_ADDRESS_CALL209)
# (RET_ADDRESS_CALL210)
# (RET_ADDRESS_CALL211)
# (RET_ADDRESS_CALL212)
# (RET_ADDRESS_CALL213)
# (RET_ADDRESS_CALL214)
# (RET_ADDRESS_CALL215)
# (RET_ADDRESS_CALL216)
# (RET_ADDRESS_CALL217)
# (RET_ADDRESS_CALL218)
# (RET_ADDRESS_CALL219)
# (RET_ADDRESS_CALL220)
# (RET_ADDRESS_CALL221)
# (RET_ADDRESS_CALL222)
# (RET_ADDRESS_CALL223)
# (RET_ADDRESS_CALL224)
# (RET_ADDRESS_CALL225)
# (RET_ADDRESS_CALL226)
# (RET_ADDRESS_CALL227)
# (RET_ADDRESS_CALL228)
# (RET_ADDRESS_CALL229)
# (RET_ADDRESS_CALL230)
# (RET_ADDRESS_CALL231)
# (RET_ADDRESS_CALL232)
# (output.create)
# (RET_ADDRESS_CALL233)
# (output.createshiftedmap)
# (LOOP_output.createshiftedmap)
# (RET_ADDRESS_CALL234)
# (output.createshiftedmap$while_exp0)
# (RET_ADDRESS_LT27)
# (RET_ADDRESS_CALL235)
# (output.createshiftedmap$while_exp1)
# (RET_ADDRESS_LT28)
# (RET_ADDRESS_CALL236)
# (output.createshiftedmap$while_end1)
# (RET_ADDRESS_EQ21)
# (output.createshiftedmap$if_true0)
# (output.createshiftedmap$if_false0)
# (output.createshiftedmap$if_end0)
# (output.createshiftedmap$while_end0)
# (output.getmap)
# (RET_ADDRESS_LT29)
# (RET_ADDRESS_GT22)
# (output.getmap$if_true0)
# (output.getmap$if_false0)
# (output.getmap$if_true1)
# (output.getmap$if_false1)
# (output.getmap$if_end1)
# (output.drawchar)
# (LOOP_output.drawchar)
# (RET_ADDRESS_CALL237)
# (output.drawchar$while_exp0)
# (RET_ADDRESS_LT30)
# (output.drawchar$if_true0)
# (output.drawchar$if_false0)
# (output.drawchar$if_end0)
# (output.drawchar$while_end0)
# (output.movecursor)
# (RET_ADDRESS_LT31)
# (RET_ADDRESS_GT23)
# (RET_ADDRESS_LT32)
# (RET_ADDRESS_GT24)
# (output.movecursor$if_true0)
# (RET_ADDRESS_CALL238)
# (output.movecursor$if_false0)
# (RET_ADDRESS_CALL239)
# (RET_ADDRESS_CALL240)
# (RET_ADDRESS_CALL241)
# (RET_ADDRESS_EQ22)
# (RET_ADDRESS_CALL242)
# (output.printchar)
# (RET_ADDRESS_CALL243)
# (RET_ADDRESS_EQ23)
# (output.printchar$if_true0)
# (RET_ADDRESS_CALL244)
# (output.printchar$if_false0)
# (RET_ADDRESS_CALL245)
# (RET_ADDRESS_EQ24)
# (output.printchar$if_true1)
# (RET_ADDRESS_CALL246)
# (output.printchar$if_false1)
# (RET_ADDRESS_CALL247)
# (output.printchar$if_true2)
# (output.printchar$if_false2)
# (RET_ADDRESS_EQ25)
# (output.printchar$if_true3)
# (RET_ADDRESS_CALL248)
# (output.printchar$if_false3)
# (output.printchar$if_end3)
# (output.printchar$if_end0)
# (output.printstring)
# (RET_ADDRESS_CALL249)
# (output.printstring$while_exp0)
# (RET_ADDRESS_LT33)
# (RET_ADDRESS_CALL250)
# (RET_ADDRESS_CALL251)
# (output.printstring$while_end0)
# (output.printint)
# (RET_ADDRESS_CALL252)
# (RET_ADDRESS_CALL253)
# (output.println)
# (RET_ADDRESS_EQ26)
# (output.println$if_true0)
# (output.println$if_false0)
# (output.backspace)
# (output.backspace$if_true0)
# (RET_ADDRESS_GT25)
# (output.backspace$if_true1)
# (output.backspace$if_false1)
# (RET_ADDRESS_EQ27)
# (output.backspace$if_true2)
# (output.backspace$if_false2)
# (output.backspace$if_end1)
# (output.backspace$if_false0)
# (output.backspace$if_end0)
# (RET_ADDRESS_CALL254)
# (screen.init)
# (RET_ADDRESS_CALL255)
# (screen.init$while_exp0)
# (RET_ADDRESS_LT34)
# (screen.init$while_end0)
# (screen.clearscreen)
# (screen.clearscreen$while_exp0)
# (RET_ADDRESS_LT35)
# (screen.clearscreen$while_end0)
# (screen.updatelocation)
# (screen.updatelocation$if_true0)
# (screen.updatelocation$if_false0)
# (screen.updatelocation$if_end0)
# (screen.setcolor)
# (screen.drawpixel)
# (LOOP_screen.drawpixel)
# (RET_ADDRESS_LT36)
# (RET_ADDRESS_GT26)
# (RET_ADDRESS_LT37)
# (RET_ADDRESS_GT27)
# (screen.drawpixel$if_true0)
# (RET_ADDRESS_CALL256)
# (screen.drawpixel$if_false0)
# (RET_ADDRESS_CALL257)
# (RET_ADDRESS_CALL258)
# (RET_ADDRESS_CALL259)
# (RET_ADDRESS_CALL260)
# (screen.drawconditional)
# (screen.drawconditional$if_true0)
# (RET_ADDRESS_CALL261)
# (screen.drawconditional$if_false0)
# (RET_ADDRESS_CALL262)
# (screen.drawconditional$if_end0)
# (screen.drawline)
# (LOOP_screen.drawline)
# (RET_ADDRESS_LT38)
# (RET_ADDRESS_GT28)
# (RET_ADDRESS_LT39)
# (RET_ADDRESS_GT29)
# (screen.drawline$if_true0)
# (RET_ADDRESS_CALL263)
# (screen.drawline$if_false0)
# (RET_ADDRESS_CALL264)
# (RET_ADDRESS_CALL265)
# (RET_ADDRESS_LT40)
# (RET_ADDRESS_LT41)
# (RET_ADDRESS_LT42)
# (screen.drawline$if_true1)
# (screen.drawline$if_false1)
# (screen.drawline$if_true2)
# (RET_ADDRESS_GT30)
# (screen.drawline$if_false2)
# (RET_ADDRESS_GT31)
# (screen.drawline$if_end2)
# (RET_ADDRESS_CALL266)
# (RET_ADDRESS_CALL267)
# (RET_ADDRESS_CALL268)
# (RET_ADDRESS_CALL269)
# (screen.drawline$while_exp0)
# (RET_ADDRESS_LT43)
# (RET_ADDRESS_LT44)
# (screen.drawline$if_true3)
# (screen.drawline$if_false3)
# (screen.drawline$if_true4)
# (screen.drawline$if_false4)
# (screen.drawline$if_end4)
# (RET_ADDRESS_CALL270)
# (screen.drawline$while_end0)
# (screen.drawrectangle)
# (LOOP_screen.drawrectangle)
# (RET_ADDRESS_GT32)
# (RET_ADDRESS_GT33)
# (RET_ADDRESS_LT45)
# (RET_ADDRESS_GT34)
# (RET_ADDRESS_LT46)
# (RET_ADDRESS_GT35)
# (screen.drawrectangle$if_true0)
# (RET_ADDRESS_CALL271)
# (screen.drawrectangle$if_false0)
# (RET_ADDRESS_CALL272)
# (RET_ADDRESS_CALL273)
# (RET_ADDRESS_CALL274)
# (RET_ADDRESS_CALL275)
# (RET_ADDRESS_CALL276)
# (screen.drawrectangle$while_exp0)
# (RET_ADDRESS_GT36)
# (RET_ADDRESS_EQ28)
# (screen.drawrectangle$if_true1)
# (RET_ADDRESS_CALL277)
# (screen.drawrectangle$if_false1)
# (RET_ADDRESS_CALL278)
# (screen.drawrectangle$while_exp1)
# (RET_ADDRESS_LT47)
# (RET_ADDRESS_CALL279)
# (screen.drawrectangle$while_end1)
# (RET_ADDRESS_CALL280)
# (screen.drawrectangle$if_end1)
# (screen.drawrectangle$while_end0)
# (screen.drawhorizontal)
# (LOOP_screen.drawhorizontal)
# (RET_ADDRESS_CALL281)
# (RET_ADDRESS_CALL282)
# (RET_ADDRESS_GT37)
# (RET_ADDRESS_LT48)
# (RET_ADDRESS_LT49)
# (RET_ADDRESS_GT38)
# (screen.drawhorizontal$if_true0)
# (RET_ADDRESS_CALL283)
# (RET_ADDRESS_CALL284)
# (RET_ADDRESS_CALL285)
# (RET_ADDRESS_CALL286)
# (RET_ADDRESS_CALL287)
# (RET_ADDRESS_CALL288)
# (RET_ADDRESS_CALL289)
# (RET_ADDRESS_EQ29)
# (screen.drawhorizontal$if_true1)
# (RET_ADDRESS_CALL290)
# (screen.drawhorizontal$if_false1)
# (RET_ADDRESS_CALL291)
# (screen.drawhorizontal$while_exp0)
# (RET_ADDRESS_LT50)
# (RET_ADDRESS_CALL292)
# (screen.drawhorizontal$while_end0)
# (RET_ADDRESS_CALL293)
# (screen.drawhorizontal$if_end1)
# (screen.drawsymetric)
# (RET_ADDRESS_CALL294)
# (RET_ADDRESS_CALL295)
# (RET_ADDRESS_CALL296)
# (RET_ADDRESS_CALL297)
# (screen.drawcircle)
# (LOOP_screen.drawcircle)
# (RET_ADDRESS_LT51)
# (RET_ADDRESS_GT39)
# (RET_ADDRESS_LT52)
# (RET_ADDRESS_GT40)
# (screen.drawcircle$if_true0)
# (RET_ADDRESS_CALL298)
# (screen.drawcircle$if_false0)
# (RET_ADDRESS_LT53)
# (RET_ADDRESS_GT41)
# (RET_ADDRESS_LT54)
# (RET_ADDRESS_GT42)
# (screen.drawcircle$if_true1)
# (RET_ADDRESS_CALL299)
# (screen.drawcircle$if_false1)
# (RET_ADDRESS_CALL300)
# (screen.drawcircle$while_exp0)
# (RET_ADDRESS_GT43)
# (RET_ADDRESS_LT55)
# (screen.drawcircle$if_true2)
# (RET_ADDRESS_CALL301)
# (screen.drawcircle$if_false2)
# (RET_ADDRESS_CALL302)
# (screen.drawcircle$if_end2)
# (RET_ADDRESS_CALL303)
# (screen.drawcircle$while_end0)
# (string.new)
# (RET_ADDRESS_CALL304)
# (RET_ADDRESS_LT56)
# (string.new$if_true0)
# (RET_ADDRESS_CALL305)
# (string.new$if_false0)
# (RET_ADDRESS_GT44)
# (string.new$if_true1)
# (RET_ADDRESS_CALL306)
# (string.new$if_false1)
# (string.dispose)
# (RET_ADDRESS_GT45)
# (string.dispose$if_true0)
# (RET_ADDRESS_CALL307)
# (string.dispose$if_false0)
# (RET_ADDRESS_CALL308)
# (string.length)
# (string.charat)
# (RET_ADDRESS_LT57)
# (RET_ADDRESS_GT46)
# (RET_ADDRESS_EQ30)
# (string.charat$if_true0)
# (RET_ADDRESS_CALL309)
# (string.charat$if_false0)
# (string.setcharat)
# (RET_ADDRESS_LT58)
# (RET_ADDRESS_GT47)
# (RET_ADDRESS_EQ31)
# (string.setcharat$if_true0)
# (RET_ADDRESS_CALL310)
# (string.setcharat$if_false0)
# (string.appendchar)
# (RET_ADDRESS_EQ32)
# (string.appendchar$if_true0)
# (RET_ADDRESS_CALL311)
# (string.appendchar$if_false0)
# (string.eraselastchar)
# (RET_ADDRESS_EQ33)
# (string.eraselastchar$if_true0)
# (RET_ADDRESS_CALL312)
# (string.eraselastchar$if_false0)
# (string.intvalue)
# (LOOP_string.intvalue)
# (RET_ADDRESS_EQ34)
# (string.intvalue$if_true0)
# (string.intvalue$if_false0)
# (RET_ADDRESS_EQ35)
# (string.intvalue$if_true1)
# (string.intvalue$if_false1)
# (RET_ADDRESS_LT59)
# (RET_ADDRESS_LT60)
# (RET_ADDRESS_GT48)
# (string.intvalue$if_true2)
# (RET_ADDRESS_CALL313)
# (string.intvalue$if_false2)
# (string.intvalue$while_end0)
# (string.intvalue$if_true3)
# (string.intvalue$if_false3)
# (string.setint)
# (LOOP_string.setint)
# (RET_ADDRESS_EQ36)
# (string.setint$if_true0)
# (RET_ADDRESS_CALL314)
# (string.setint$if_false0)
# (RET_ADDRESS_CALL315)
# (RET_ADDRESS_LT61)
# (string.setint$if_true1)
# (string.setint$if_false1)
# (string.setint$while_exp0)
# (RET_ADDRESS_GT49)
# (RET_ADDRESS_CALL316)
# (RET_ADDRESS_CALL317)
# (string.setint$while_end0)
# (string.setint$if_true2)
# (string.setint$if_false2)
# (RET_ADDRESS_LT62)
# (string.setint$if_true3)
# (RET_ADDRESS_CALL318)
# (string.setint$if_false3)
# (RET_ADDRESS_EQ37)
# (string.setint$if_true4)
# (string.setint$if_false4)
# (string.setint$while_exp1)
# (RET_ADDRESS_LT63)
# (string.setint$while_end1)
# (RET_ADDRESS_CALL319)
# (string.newline)
# (string.backspace)
# (string.doublequote)
# (sys.init)
# (RET_ADDRESS_CALL320)
# (RET_ADDRESS_CALL321)
# (RET_ADDRESS_CALL322)
# (RET_ADDRESS_CALL323)
# (RET_ADDRESS_CALL324)
# (RET_ADDRESS_CALL325)
# (RET_ADDRESS_CALL326)
# (sys.halt)
# (sys.halt$while_end0)
# (RET_ADDRESS_LT64)
# (sys.wait$if_true0)
# (RET_ADDRESS_CALL327)
# (sys.wait$if_false0)
# (RET_ADDRESS_GT50)
# (sys.wait$while_exp1)
# (RET_ADDRESS_GT51)
# (sys.wait$while_end1)
# (sys.wait$while_end0)
# (sys.error)
# (RET_ADDRESS_CALL328)
# (RET_ADDRESS_CALL329)
# (RET_ADDRESS_CALL330)
# (RET_ADDRESS_CALL331)
# (RET_ADDRESS_CALL332)
# (RET_ADDRESS_CALL333)
# (RET_ADDRESS_CALL334)

# %%
symbols
# Out:
# {'R0': 0,
#  'R1': 1,
#  'R2': 2,
#  'R3': 3,
#  'R4': 4,
#  'R5': 5,
#  'R6': 6,
#  'R7': 7,
#  'R8': 8,
#  'R9': 9,
#  'R1O': 10,
#  'R11': 11,
#  'R12': 12,
#  'R13': 13,
#  'R14': 14,
#  'R15': 15,
#  'SCREEN': 16384,
#  'KBD': 24576,
#  'SP': 0,
#  'LCL': 1,
#  'ARG': 2,
#  'THIS': 3,
#  'THAT': 4,
#  'END_EQ': 19,
#  'END_GT': 35,
#  'END_LT': 51,
#  'RET_ADDRESS_CALL0': 145,
#  'RET_ADDRESS_CALL1': 164,
#  'RET_ADDRESS_CALL2': 334,
#  'ball.dispose': 347,
#  'RET_ADDRESS_CALL3': 377,
#  'ball.show': 388,
#  'RET_ADDRESS_CALL4': 419,
#  'RET_ADDRESS_CALL5': 442,
#  'ball.hide': 453,
#  'RET_ADDRESS_CALL6': 481,
#  'RET_ADDRESS_CALL7': 504,
#  'ball.draw': 515,
#  'RET_ADDRESS_CALL8': 589,
#  'ball.getleft': 600,
#  'ball.getright': 621,
#  'ball.setdestination': 653,
#  'LOOP_ball.setdestination': 655,
#  'RET_ADDRESS_CALL9': 748,
#  'RET_ADDRESS_CALL10': 775,
#  'RET_ADDRESS_LT0': 799,
#  'ball.setdestination$if_true0': 827,
#  'RET_ADDRESS_LT1': 887,
#  'RET_ADDRESS_LT2': 917,
#  'ball.setdestination$if_false0': 931,
#  'RET_ADDRESS_LT3': 949,
#  'RET_ADDRESS_LT4': 980,
#  'ball.setdestination$if_end0': 992,
#  'RET_ADDRESS_CALL11': 1017,
#  'RET_ADDRESS_CALL12': 1063,
#  'RET_ADDRESS_CALL13': 1110,
#  'ball.move': 1127,
#  'RET_ADDRESS_CALL14': 1157,
#  'RET_ADDRESS_LT5': 1179,
#  'ball.move$if_true0': 1186,
#  'ball.move$if_false0': 1220,
#  'ball.move$if_true1': 1268,
#  'ball.move$if_true2': 1284,
#  'ball.move$if_false2': 1310,
#  'ball.move$if_end2': 1334,
#  'ball.move$if_false1': 1336,
#  'ball.move$if_true3': 1352,
#  'ball.move$if_false3': 1378,
#  'ball.move$if_end3': 1402,
#  'ball.move$if_end0': 1403,
#  'ball.move$if_true4': 1419,
#  'ball.move$if_true5': 1435,
#  'ball.move$if_false5': 1461,
#  'ball.move$if_end5': 1485,
#  'ball.move$if_false4': 1487,
#  'ball.move$if_true6': 1503,
#  'ball.move$if_false6': 1529,
#  'ball.move$if_end6': 1553,
#  'RET_ADDRESS_GT0': 1574,
#  'ball.move$if_true7': 1584,
#  'ball.move$if_false7': 1615,
#  'RET_ADDRESS_LT6': 1635,
#  'ball.move$if_true8': 1645,
#  'ball.move$if_false8': 1678,
#  'RET_ADDRESS_GT1': 1698,
#  'ball.move$if_true9': 1708,
#  'ball.move$if_false9': 1741,
#  'RET_ADDRESS_LT7': 1761,
#  'ball.move$if_true10': 1771,
#  'ball.move$if_false10': 1804,
#  'RET_ADDRESS_CALL15': 1822,
#  'ball.bounce': 1838,
#  'LOOP_ball.bounce': 1840,
#  'RET_ADDRESS_CALL16': 1885,
#  'RET_ADDRESS_CALL17': 1919,
#  'RET_ADDRESS_EQ0': 1942,
#  'ball.bounce$if_true0': 1949,
#  'ball.bounce$if_false0': 1966,
#  'RET_ADDRESS_LT8': 1982,
#  'RET_ADDRESS_EQ1': 2000,
#  'RET_ADDRESS_LT9': 2021,
#  'RET_ADDRESS_EQ2': 2045,
#  'ball.bounce$if_true1': 2057,
#  'ball.bounce$if_false1': 2074,
#  'ball.bounce$if_end1': 2089,
#  'RET_ADDRESS_EQ3': 2107,
#  'ball.bounce$if_true2': 2114,
#  'RET_ADDRESS_CALL18': 2157,
#  'RET_ADDRESS_CALL19': 2177,
#  'RET_ADDRESS_CALL20': 2218,
#  'ball.bounce$if_false2': 2231,
#  'RET_ADDRESS_EQ4': 2250,
#  'ball.bounce$if_true3': 2257,
#  'RET_ADDRESS_CALL21': 2294,
#  'RET_ADDRESS_CALL22': 2314,
#  'RET_ADDRESS_CALL23': 2355,
#  'ball.bounce$if_false3': 2368,
#  'RET_ADDRESS_EQ5': 2387,
#  'ball.bounce$if_true4': 2394,
#  'RET_ADDRESS_CALL24': 2436,
#  'RET_ADDRESS_CALL25': 2457,
#  'RET_ADDRESS_CALL26': 2498,
#  'ball.bounce$if_false4': 2511,
#  'RET_ADDRESS_CALL27': 2547,
#  'RET_ADDRESS_CALL28': 2568,
#  'RET_ADDRESS_CALL29': 2609,
#  'ball.bounce$if_end4': 2620,
#  'ball.bounce$if_end2': 2621,
#  'RET_ADDRESS_CALL30': 2653,
#  'bat.new': 2664,
#  'RET_ADDRESS_CALL31': 2682,
#  'RET_ADDRESS_CALL32': 2778,
#  'bat.dispose': 2791,
#  'RET_ADDRESS_CALL33': 2821,
#  'bat.show': 2832,
#  'RET_ADDRESS_CALL34': 2863,
#  'RET_ADDRESS_CALL35': 2886,
#  'bat.hide': 2897,
#  'RET_ADDRESS_CALL36': 2925,
#  'RET_ADDRESS_CALL37': 2948,
#  'bat.draw': 2959,
#  'RET_ADDRESS_CALL38': 3038,
#  'bat.setdirection': 3049,
#  'bat.getleft': 3083,
#  'bat.getright': 3104,
#  'bat.setwidth': 3138,
#  'RET_ADDRESS_CALL39': 3168,
#  'RET_ADDRESS_CALL40': 3205,
#  'bat.move': 3216,
#  'RET_ADDRESS_EQ6': 3245,
#  'bat.move$if_true0': 3252,
#  'RET_ADDRESS_LT10': 3291,
#  'bat.move$if_true1': 3298,
#  'bat.move$if_false1': 3308,
#  'RET_ADDRESS_CALL41': 3324,
#  'RET_ADDRESS_CALL42': 3429,
#  'RET_ADDRESS_CALL43': 3453,
#  'RET_ADDRESS_CALL44': 3523,
#  'bat.move$if_false0': 3530,
#  'RET_ADDRESS_GT2': 3584,
#  'bat.move$if_true2': 3591,
#  'bat.move$if_false2': 3616,
#  'RET_ADDRESS_CALL45': 3632,
#  'RET_ADDRESS_CALL46': 3711,
#  'RET_ADDRESS_CALL47': 3735,
#  'RET_ADDRESS_CALL48': 3831,
#  'bat.move$if_end0': 3836,
#  'main.main': 3842,
#  'RET_ADDRESS_CALL49': 3858,
#  'RET_ADDRESS_CALL50': 3875,
#  'RET_ADDRESS_CALL51': 3900,
#  'RET_ADDRESS_CALL52': 3924,
#  'ponggame.new': 3935,
#  'RET_ADDRESS_CALL53': 3953,
#  'RET_ADDRESS_CALL54': 3970,
#  'RET_ADDRESS_CALL55': 4031,
#  'RET_ADDRESS_CALL56': 4081,
#  'RET_ADDRESS_CALL57': 4116,
#  'RET_ADDRESS_CALL58': 4155,
#  'RET_ADDRESS_CALL59': 4182,
#  'RET_ADDRESS_CALL60': 4205,
#  'RET_ADDRESS_CALL61': 4223,
#  'RET_ADDRESS_CALL62': 4241,
#  'RET_ADDRESS_CALL63': 4259,
#  'RET_ADDRESS_CALL64': 4277,
#  'RET_ADDRESS_CALL65': 4295,
#  'RET_ADDRESS_CALL66': 4313,
#  'RET_ADDRESS_CALL67': 4331,
#  'RET_ADDRESS_CALL68': 4349,
#  'RET_ADDRESS_CALL69': 4361,
#  'ponggame.dispose': 4424,
#  'RET_ADDRESS_CALL70': 4455,
#  'RET_ADDRESS_CALL71': 4479,
#  'RET_ADDRESS_CALL72': 4502,
#  'ponggame.newinstance': 4513,
#  'RET_ADDRESS_CALL73': 4525,
#  'ponggame.getinstance': 4536,
#  'ponggame.run': 4544,
#  'ponggame.run$while_exp0': 4560,
#  'ponggame.run$while_exp1': 4580,
#  'RET_ADDRESS_EQ7': 4595,
#  'RET_ADDRESS_CALL74': 4632,
#  'RET_ADDRESS_CALL75': 4657,
#  'RET_ADDRESS_CALL76': 4680,
#  'ponggame.run$while_end1': 4687,
#  'RET_ADDRESS_EQ8': 4704,
#  'ponggame.run$if_true0': 4711,
#  'RET_ADDRESS_CALL77': 4734,
#  'ponggame.run$if_false0': 4741,
#  'RET_ADDRESS_EQ9': 4758,
#  'ponggame.run$if_true1': 4765,
#  'RET_ADDRESS_CALL78': 4790,
#  'ponggame.run$if_false1': 4797,
#  'RET_ADDRESS_EQ10': 4814,
#  'ponggame.run$if_true2': 4821,
#  'ponggame.run$if_false2': 4836,
#  'ponggame.run$if_end0': 4837,
#  'RET_ADDRESS_EQ11': 4853,
#  'RET_ADDRESS_CALL79': 4893,
#  'RET_ADDRESS_CALL80': 4918,
#  'RET_ADDRESS_CALL81': 4941,
#  'ponggame.run$while_end2': 4948,
#  'ponggame.run$while_end0': 4950,
#  'ponggame.run$if_true3': 4966,
#  'RET_ADDRESS_CALL82': 4990,
#  'RET_ADDRESS_CALL83': 5013,
#  'RET_ADDRESS_CALL84': 5031,
#  'RET_ADDRESS_CALL85': 5049,
#  'RET_ADDRESS_CALL86': 5067,
#  'RET_ADDRESS_CALL87': 5085,
#  'RET_ADDRESS_CALL88': 5103,
#  'RET_ADDRESS_CALL89': 5121,
#  'RET_ADDRESS_CALL90': 5139,
#  'RET_ADDRESS_CALL91': 5157,
#  'RET_ADDRESS_CALL92': 5175,
#  'RET_ADDRESS_CALL93': 5187,
#  'ponggame.run$if_false3': 5192,
#  'ponggame.moveball': 5198,
#  'LOOP_ponggame.moveball': 5200,
#  'RET_ADDRESS_CALL94': 5238,
#  'RET_ADDRESS_GT3': 5261,
#  'RET_ADDRESS_EQ12': 5282,
#  'ponggame.moveball$if_true0': 5297,
#  'RET_ADDRESS_CALL95': 5344,
#  'RET_ADDRESS_CALL96': 5369,
#  'RET_ADDRESS_CALL97': 5395,
#  'RET_ADDRESS_CALL98': 5422,
#  'RET_ADDRESS_EQ13': 5449,
#  'ponggame.moveball$if_true1': 5456,
#  'RET_ADDRESS_GT4': 5476,
#  'RET_ADDRESS_LT11': 5497,
#  'ponggame.moveball$if_true2': 5529,
#  'RET_ADDRESS_LT12': 5560,
#  'ponggame.moveball$if_true3': 5567,
#  'ponggame.moveball$if_false3': 5583,
#  'RET_ADDRESS_GT5': 5615,
#  'ponggame.moveball$if_true4': 5622,
#  'ponggame.moveball$if_false4': 5632,
#  'RET_ADDRESS_CALL99': 5692,
#  'RET_ADDRESS_CALL100': 5748,
#  'RET_ADDRESS_CALL101': 5774,
#  'ponggame.moveball$if_false2': 5779,
#  'RET_ADDRESS_CALL102': 5806,
#  'ponggame.moveball$if_false0': 5811,
#  'array.new': 5817,
#  'RET_ADDRESS_GT6': 5832,
#  'array.new$if_true0': 5842,
#  'RET_ADDRESS_CALL103': 5860,
#  'array.new$if_false0': 5865,
#  'RET_ADDRESS_CALL104': 5884,
#  'array.dispose': 5886,
#  'RET_ADDRESS_CALL105': 5916,
#  'keyboard.init': 5927,
#  'keyboard.keypressed': 5933,
#  'RET_ADDRESS_CALL106': 5951,
#  'keyboard.readchar': 5953,
#  'RET_ADDRESS_CALL107': 5976,
#  'keyboard.readchar$while_exp0': 5981,
#  'RET_ADDRESS_EQ14': 5996,
#  'RET_ADDRESS_GT7': 6011,
#  'RET_ADDRESS_CALL108': 6036,
#  'RET_ADDRESS_GT8': 6057,
#  'keyboard.readchar$if_true0': 6064,
#  'keyboard.readchar$if_false0': 6077,
#  'keyboard.readchar$while_end0': 6079,
#  'RET_ADDRESS_CALL109': 6091,
#  'RET_ADDRESS_CALL110': 6103,
#  'RET_ADDRESS_CALL111': 6127,
#  'keyboard.readline': 6141,
#  'LOOP_keyboard.readline': 6143,
#  'RET_ADDRESS_CALL112': 6168,
#  'RET_ADDRESS_CALL113': 6195,
#  'RET_ADDRESS_CALL114': 6212,
#  'RET_ADDRESS_CALL115': 6230,
#  'keyboard.readline$while_exp0': 6237,
#  'RET_ADDRESS_CALL116': 6269,
#  'RET_ADDRESS_EQ15': 6293,
#  'keyboard.readline$if_true0': 6321,
#  'RET_ADDRESS_EQ16': 6340,
#  'keyboard.readline$if_true1': 6347,
#  'RET_ADDRESS_CALL117': 6368,
#  'keyboard.readline$if_false1': 6375,
#  'RET_ADDRESS_CALL118': 6403,
#  'keyboard.readline$if_end1': 6411,
#  'keyboard.readline$while_end0': 6414,
#  'keyboard.readint': 6425,
#  'RET_ADDRESS_CALL119': 6451,
#  'RET_ADDRESS_CALL120': 6476,
#  'RET_ADDRESS_CALL121': 6501,
#  'math.init': 6515,
#  'RET_ADDRESS_CALL122': 6537,
#  'RET_ADDRESS_CALL123': 6560,
#  'math.init$while_exp0': 6606,
#  'RET_ADDRESS_LT13': 6623,
#  'math.init$while_end0': 6778,
#  'math.abs': 6784,
#  'RET_ADDRESS_LT14': 6799,
#  'math.abs$if_true0': 6806,
#  'math.abs$if_false0': 6823,
#  'math.multiply': 6832,
#  'LOOP_math.multiply': 6834,
#  'RET_ADDRESS_LT15': 6856,
#  'RET_ADDRESS_GT9': 6871,
#  'RET_ADDRESS_GT10': 6891,
#  'RET_ADDRESS_LT16': 6906,
#  'RET_ADDRESS_CALL124': 6944,
#  'RET_ADDRESS_CALL125': 6969,
#  'RET_ADDRESS_LT17': 6993,
#  'math.multiply$if_true0': 7000,
#  'math.multiply$if_false0': 7039,
#  'RET_ADDRESS_LT18': 7059,
#  'RET_ADDRESS_GT11': 7119,
#  'math.multiply$if_true1': 7126,
#  'math.multiply$if_false1': 7203,
#  'math.multiply$while_end0': 7256,
#  'math.multiply$if_true2': 7272,
#  'math.multiply$if_false2': 7289,
#  'math.divide': 7298,
#  'LOOP_math.divide': 7300,
#  'RET_ADDRESS_EQ17': 7322,
#  'math.divide$if_true0': 7329,
#  'RET_ADDRESS_CALL126': 7347,
#  'math.divide$if_false0': 7352,
#  'RET_ADDRESS_LT19': 7367,
#  'RET_ADDRESS_GT12': 7382,
#  'RET_ADDRESS_GT13': 7402,
#  'RET_ADDRESS_LT20': 7417,
#  'RET_ADDRESS_CALL127': 7468,
#  'RET_ADDRESS_CALL128': 7509,
#  'math.divide$while_exp0': 7515,
#  'RET_ADDRESS_LT21': 7610,
#  'math.divide$if_true1': 7637,
#  'RET_ADDRESS_GT14': 7801,
#  'math.divide$if_true2': 7828,
#  'math.divide$if_false2': 7850,
#  'math.divide$while_end0': 7853,
#  'RET_ADDRESS_GT15': 7873,
#  'RET_ADDRESS_GT16': 7922,
#  'math.divide$if_true3': 7932,
#  'math.divide$if_false3': 8028,
#  'math.divide$while_end1': 8052,
#  'math.divide$if_true4': 8067,
#  'math.divide$if_false4': 8084,
#  'math.sqrt': 8093,
#  'LOOP_math.sqrt': 8095,
#  'RET_ADDRESS_LT22': 8117,
#  'math.sqrt$if_true0': 8124,
#  'RET_ADDRESS_CALL129': 8142,
#  'math.sqrt$if_false0': 8147,
#  'math.sqrt$while_exp0': 8159,
#  'RET_ADDRESS_GT17': 8178,
#  'RET_ADDRESS_CALL130': 8262,
#  'RET_ADDRESS_GT18': 8288,
#  'RET_ADDRESS_LT23': 8307,
#  'math.sqrt$if_true1': 8322,
#  'math.sqrt$if_false1': 8337,
#  'math.sqrt$while_end0': 8361,
#  'math.max': 8372,
#  'RET_ADDRESS_GT19': 8390,
#  'math.max$if_true0': 8397,
#  'math.max$if_false0': 8410,
#  'math.min': 8419,
#  'RET_ADDRESS_LT24': 8437,
#  'math.min$if_true0': 8444,
#  'math.min$if_false0': 8457,
#  'memory.init': 8466,
#  'memory.peek': 8571,
#  'memory.poke': 8603,
#  'memory.alloc': 8656,
#  'RET_ADDRESS_LT25': 8675,
#  'memory.alloc$if_true0': 8682,
#  'RET_ADDRESS_CALL131': 8700,
#  'memory.alloc$if_false0': 8705,
#  'memory.alloc$while_exp0': 8717,
#  'RET_ADDRESS_LT26': 8756,
#  'memory.alloc$while_end0': 8800,
#  'RET_ADDRESS_GT20': 8829,
#  'memory.alloc$if_true1': 8836,
#  'RET_ADDRESS_CALL132': 8854,
#  'memory.alloc$if_false1': 8859,
#  'RET_ADDRESS_GT21': 8909,
#  'memory.alloc$if_true2': 8916,
#  'RET_ADDRESS_EQ18': 9069,
#  'memory.alloc$if_true3': 9076,
#  'memory.alloc$if_false3': 9160,
#  'memory.alloc$if_end3': 9240,
#  'memory.alloc$if_false2': 9308,
#  'memory.dealloc': 9370,
#  'RET_ADDRESS_EQ19': 9471,
#  'memory.dealloc$if_true0': 9478,
#  'memory.dealloc$if_false0': 9569,
#  'RET_ADDRESS_EQ20': 9730,
#  'memory.dealloc$if_true1': 9737,
#  'memory.dealloc$if_false1': 9795,
#  'memory.dealloc$if_end1': 9861,
#  'output.init': 9868,
#  'RET_ADDRESS_CALL133': 9929,
#  'RET_ADDRESS_CALL134': 9946,
#  'RET_ADDRESS_CALL135': 9963,
#  'output.initmap': 9974,
#  'RET_ADDRESS_CALL136': 9992,
#  'RET_ADDRESS_CALL137': 10075,
#  'RET_ADDRESS_CALL138': 10142,
#  'RET_ADDRESS_CALL139': 10225,
#  'RET_ADDRESS_CALL140': 10298,
#  'RET_ADDRESS_CALL141': 10381,
#  'RET_ADDRESS_CALL142': 10468,
#  'RET_ADDRESS_CALL143': 10549,
#  'RET_ADDRESS_CALL144': 10634,
#  'RET_ADDRESS_CALL145': 10707,
#  'RET_ADDRESS_CALL146': 10792,
#  'RET_ADDRESS_CALL147': 10877,
#  'RET_ADDRESS_CALL148': 10954,
#  'RET_ADDRESS_CALL149': 11031,
#  'RET_ADDRESS_CALL150': 11104,
#  'RET_ADDRESS_CALL151': 11173,
#  'RET_ADDRESS_CALL152': 11244,
#  'RET_ADDRESS_CALL153': 11323,
#  'RET_ADDRESS_CALL154': 11408,
#  'RET_ADDRESS_CALL155': 11493,
#  'RET_ADDRESS_CALL156': 11578,
#  'RET_ADDRESS_CALL157': 11663,
#  'RET_ADDRESS_CALL158': 11748,
#  'RET_ADDRESS_CALL159': 11833,
#  'RET_ADDRESS_CALL160': 11918,
#  'RET_ADDRESS_CALL161': 12003,
#  'RET_ADDRESS_CALL162': 12088,
#  'RET_ADDRESS_CALL163': 12173,
#  'RET_ADDRESS_CALL164': 12248,
#  'RET_ADDRESS_CALL165': 12325,
#  'RET_ADDRESS_CALL166': 12406,
#  'RET_ADDRESS_CALL167': 12477,
#  'RET_ADDRESS_CALL168': 12558,
#  'RET_ADDRESS_CALL169': 12643,
#  'RET_ADDRESS_CALL170': 12726,
#  'RET_ADDRESS_CALL171': 12811,
#  'RET_ADDRESS_CALL172': 12896,
#  'RET_ADDRESS_CALL173': 12981,
#  'RET_ADDRESS_CALL174': 13066,
#  'RET_ADDRESS_CALL175': 13151,
#  'RET_ADDRESS_CALL176': 13236,
#  'RET_ADDRESS_CALL177': 13321,
#  'RET_ADDRESS_CALL178': 13406,
#  'RET_ADDRESS_CALL179': 13491,
#  'RET_ADDRESS_CALL180': 13576,
#  'RET_ADDRESS_CALL181': 13661,
#  'RET_ADDRESS_CALL182': 13746,
#  'RET_ADDRESS_CALL183': 13831,
#  'RET_ADDRESS_CALL184': 13916,
#  'RET_ADDRESS_CALL185': 14001,
#  'RET_ADDRESS_CALL186': 14086,
#  'RET_ADDRESS_CALL187': 14173,
#  'RET_ADDRESS_CALL188': 14258,
#  'RET_ADDRESS_CALL189': 14343,
#  'RET_ADDRESS_CALL190': 14428,
#  'RET_ADDRESS_CALL191': 14513,
#  'RET_ADDRESS_CALL192': 14598,
#  'RET_ADDRESS_CALL193': 14683,
#  'RET_ADDRESS_CALL194': 14768,
#  'RET_ADDRESS_CALL195': 14853,
#  'RET_ADDRESS_CALL196': 14938,
#  'RET_ADDRESS_CALL197': 15023,
#  'RET_ADDRESS_CALL198': 15102,
#  'RET_ADDRESS_CALL199': 15187,
#  'RET_ADDRESS_CALL200': 15260,
#  'RET_ADDRESS_CALL201': 15329,
#  'RET_ADDRESS_CALL202': 15402,
#  'RET_ADDRESS_CALL203': 15481,
#  'RET_ADDRESS_CALL204': 15566,
#  'RET_ADDRESS_CALL205': 15645,
#  'RET_ADDRESS_CALL206': 15730,
#  'RET_ADDRESS_CALL207': 15809,
#  'RET_ADDRESS_CALL208': 15894,
#  'RET_ADDRESS_CALL209': 15977,
#  'RET_ADDRESS_CALL210': 16062,
#  'RET_ADDRESS_CALL211': 16145,
#  'RET_ADDRESS_CALL212': 16230,
#  'RET_ADDRESS_CALL213': 16315,
#  'RET_ADDRESS_CALL214': 16400,
#  'RET_ADDRESS_CALL215': 16479,
#  'RET_ADDRESS_CALL216': 16558,
#  'RET_ADDRESS_CALL217': 16637,
#  'RET_ADDRESS_CALL218': 16718,
#  'RET_ADDRESS_CALL219': 16799,
#  'RET_ADDRESS_CALL220': 16878,
#  'RET_ADDRESS_CALL221': 16957,
#  'RET_ADDRESS_CALL222': 17042,
#  'RET_ADDRESS_CALL223': 17121,
#  'RET_ADDRESS_CALL224': 17200,
#  'RET_ADDRESS_CALL225': 17279,
#  'RET_ADDRESS_CALL226': 17358,
#  'RET_ADDRESS_CALL227': 17439,
#  'RET_ADDRESS_CALL228': 17518,
#  'RET_ADDRESS_CALL229': 17603,
#  'RET_ADDRESS_CALL230': 17688,
#  'RET_ADDRESS_CALL231': 17773,
#  'RET_ADDRESS_CALL232': 17846,
#  'output.create': 17857,
#  'RET_ADDRESS_CALL233': 17879,
#  'output.createshiftedmap': 18470,
#  'LOOP_output.createshiftedmap': 18472,
#  'RET_ADDRESS_CALL234': 18497,
#  'output.createshiftedmap$while_exp0': 18513,
#  'RET_ADDRESS_LT27': 18531,
#  'RET_ADDRESS_CALL235': 18594,
#  'output.createshiftedmap$while_exp1': 18660,
#  'RET_ADDRESS_LT28': 18679,
#  'RET_ADDRESS_CALL236': 18759,
#  'output.createshiftedmap$while_end1': 18809,
#  'RET_ADDRESS_EQ21': 18825,
#  'output.createshiftedmap$if_true0': 18832,
#  'output.createshiftedmap$if_false0': 18847,
#  'output.createshiftedmap$if_end0': 18871,
#  'output.createshiftedmap$while_end0': 18873,
#  'output.getmap': 18879,
#  'RET_ADDRESS_LT29': 18900,
#  'RET_ADDRESS_GT22': 18917,
#  'output.getmap$if_true0': 18929,
#  'output.getmap$if_false0': 18939,
#  'output.getmap$if_true1': 18952,
#  'output.getmap$if_false1': 18990,
#  'output.getmap$if_end1': 19026,
#  'output.drawchar': 19035,
#  'LOOP_output.drawchar': 19037,
#  'RET_ADDRESS_CALL237': 19063,
#  'output.drawchar$while_exp0': 19082,
#  'RET_ADDRESS_LT30': 19099,
#  'output.drawchar$if_true0': 19120,
#  'output.drawchar$if_false0': 19175,
#  'output.drawchar$if_end0': 19224,
#  'output.drawchar$while_end0': 19358,
#  'output.movecursor': 19364,
#  'RET_ADDRESS_LT31': 19379,
#  'RET_ADDRESS_GT23': 19396,
#  'RET_ADDRESS_LT32': 19416,
#  'RET_ADDRESS_GT24': 19438,
#  'output.movecursor$if_true0': 19450,
#  'RET_ADDRESS_CALL238': 19468,
#  'output.movecursor$if_false0': 19473,
#  'RET_ADDRESS_CALL239': 19498,
#  'RET_ADDRESS_CALL240': 19534,
#  'RET_ADDRESS_CALL241': 19586,
#  'RET_ADDRESS_EQ22': 19590,
#  'RET_ADDRESS_CALL242': 19613,
#  'output.printchar': 19624,
#  'RET_ADDRESS_CALL243': 19643,
#  'RET_ADDRESS_EQ23': 19647,
#  'output.printchar$if_true0': 19654,
#  'RET_ADDRESS_CALL244': 19666,
#  'output.printchar$if_false0': 19673,
#  'RET_ADDRESS_CALL245': 19692,
#  'RET_ADDRESS_EQ24': 19696,
#  'output.printchar$if_true1': 19703,
#  'RET_ADDRESS_CALL246': 19715,
#  'output.printchar$if_false1': 19722,
#  'RET_ADDRESS_CALL247': 19741,
#  'output.printchar$if_true2': 19762,
#  'output.printchar$if_false2': 19802,
#  'RET_ADDRESS_EQ25': 19818,
#  'output.printchar$if_true3': 19825,
#  'RET_ADDRESS_CALL248': 19837,
#  'output.printchar$if_false3': 19844,
#  'output.printchar$if_end3': 19858,
#  'output.printchar$if_end0': 19859,
#  'output.printstring': 19865,
#  'RET_ADDRESS_CALL249': 19891,
#  'output.printstring$while_exp0': 19897,
#  'RET_ADDRESS_LT33': 19915,
#  'RET_ADDRESS_CALL250': 19949,
#  'RET_ADDRESS_CALL251': 19961,
#  'output.printstring$while_end0': 19990,
#  'output.printint': 19996,
#  'RET_ADDRESS_CALL252': 20021,
#  'RET_ADDRESS_CALL253': 20044,
#  'output.println': 20055,
#  'RET_ADDRESS_EQ26': 20125,
#  'output.println$if_true0': 20132,
#  'output.println$if_false0': 20143,
#  'output.backspace': 20149,
#  'output.backspace$if_true0': 20162,
#  'RET_ADDRESS_GT25': 20176,
#  'output.backspace$if_true1': 20183,
#  'output.backspace$if_false1': 20225,
#  'RET_ADDRESS_EQ27': 20252,
#  'output.backspace$if_true2': 20259,
#  'output.backspace$if_false2': 20270,
#  'output.backspace$if_end1': 20292,
#  'output.backspace$if_false0': 20303,
#  'output.backspace$if_end0': 20315,
#  'RET_ADDRESS_CALL254': 20333,
#  'screen.init': 20344,
#  'RET_ADDRESS_CALL255': 20389,
#  'screen.init$while_exp0': 20435,
#  'RET_ADDRESS_LT34': 20452,
#  'screen.init$while_end0': 20607,
#  'screen.clearscreen': 20613,
#  'screen.clearscreen$while_exp0': 20617,
#  'RET_ADDRESS_LT35': 20634,
#  'screen.clearscreen$while_end0': 20710,
#  'screen.updatelocation': 20716,
#  'screen.updatelocation$if_true0': 20729,
#  'screen.updatelocation$if_false0': 20813,
#  'screen.updatelocation$if_end0': 20898,
#  'screen.setcolor': 20904,
#  'screen.drawpixel': 20922,
#  'LOOP_screen.drawpixel': 20924,
#  'RET_ADDRESS_LT36': 20946,
#  'RET_ADDRESS_GT26': 20963,
#  'RET_ADDRESS_LT37': 20983,
#  'RET_ADDRESS_GT27': 21005,
#  'screen.drawpixel$if_true0': 21017,
#  'RET_ADDRESS_CALL256': 21035,
#  'screen.drawpixel$if_false0': 21040,
#  'RET_ADDRESS_CALL257': 21065,
#  'RET_ADDRESS_CALL258': 21103,
#  'RET_ADDRESS_CALL259': 21139,
#  'RET_ADDRESS_CALL260': 21208,
#  'screen.drawconditional': 21219,
#  'screen.drawconditional$if_true0': 21234,
#  'RET_ADDRESS_CALL261': 21260,
#  'screen.drawconditional$if_false0': 21267,
#  'RET_ADDRESS_CALL262': 21293,
#  'screen.drawconditional$if_end0': 21298,
#  'screen.drawline': 21304,
#  'LOOP_screen.drawline': 21306,
#  'RET_ADDRESS_LT38': 21328,
#  'RET_ADDRESS_GT28': 21346,
#  'RET_ADDRESS_LT39': 21366,
#  'RET_ADDRESS_GT29': 21390,
#  'screen.drawline$if_true0': 21402,
#  'RET_ADDRESS_CALL263': 21420,
#  'screen.drawline$if_false0': 21425,
#  'RET_ADDRESS_CALL264': 21457,
#  'RET_ADDRESS_CALL265': 21498,
#  'RET_ADDRESS_LT40': 21526,
#  'RET_ADDRESS_LT41': 21566,
#  'RET_ADDRESS_LT42': 21602,
#  'screen.drawline$if_true1': 21619,
#  'screen.drawline$if_false1': 21713,
#  'screen.drawline$if_true2': 21729,
#  'RET_ADDRESS_GT30': 21845,
#  'screen.drawline$if_false2': 21859,
#  'RET_ADDRESS_GT31': 21925,
#  'screen.drawline$if_end2': 21937,
#  'RET_ADDRESS_CALL266': 21963,
#  'RET_ADDRESS_CALL267': 22013,
#  'RET_ADDRESS_CALL268': 22065,
#  'RET_ADDRESS_CALL269': 22112,
#  'screen.drawline$while_exp0': 22117,
#  'RET_ADDRESS_LT43': 22137,
#  'RET_ADDRESS_LT44': 22162,
#  'screen.drawline$if_true3': 22169,
#  'screen.drawline$if_false3': 22204,
#  'screen.drawline$if_true4': 22253,
#  'screen.drawline$if_false4': 22277,
#  'screen.drawline$if_end4': 22299,
#  'RET_ADDRESS_CALL270': 22357,
#  'screen.drawline$while_end0': 22364,
#  'screen.drawrectangle': 22370,
#  'LOOP_screen.drawrectangle': 22372,
#  'RET_ADDRESS_GT32': 22398,
#  'RET_ADDRESS_GT33': 22418,
#  'RET_ADDRESS_LT45': 22438,
#  'RET_ADDRESS_GT34': 22461,
#  'RET_ADDRESS_LT46': 22481,
#  'RET_ADDRESS_GT35': 22505,
#  'screen.drawrectangle$if_true0': 22517,
#  'RET_ADDRESS_CALL271': 22535,
#  'screen.drawrectangle$if_false0': 22540,
#  'RET_ADDRESS_CALL272': 22565,
#  'RET_ADDRESS_CALL273': 22607,
#  'RET_ADDRESS_CALL274': 22650,
#  'RET_ADDRESS_CALL275': 22694,
#  'RET_ADDRESS_CALL276': 22851,
#  'screen.drawrectangle$while_exp0': 22901,
#  'RET_ADDRESS_GT36': 22921,
#  'RET_ADDRESS_EQ28': 22974,
#  'screen.drawrectangle$if_true1': 22981,
#  'RET_ADDRESS_CALL277': 23023,
#  'screen.drawrectangle$if_false1': 23030,
#  'RET_ADDRESS_CALL278': 23058,
#  'screen.drawrectangle$while_exp1': 23085,
#  'RET_ADDRESS_LT47': 23103,
#  'RET_ADDRESS_CALL279': 23138,
#  'screen.drawrectangle$while_end1': 23167,
#  'RET_ADDRESS_CALL280': 23195,
#  'screen.drawrectangle$if_end1': 23200,
#  'screen.drawrectangle$while_end0': 23261,
#  'screen.drawhorizontal': 23267,
#  'LOOP_screen.drawhorizontal': 23269,
#  'RET_ADDRESS_CALL281': 23303,
#  'RET_ADDRESS_CALL282': 23342,
#  'RET_ADDRESS_GT37': 23373,
#  'RET_ADDRESS_LT48': 23390,
#  'RET_ADDRESS_LT49': 23414,
#  'RET_ADDRESS_GT38': 23440,
#  'screen.drawhorizontal$if_true0': 23452,
#  'RET_ADDRESS_CALL283': 23477,
#  'RET_ADDRESS_CALL284': 23516,
#  'RET_ADDRESS_CALL285': 23555,
#  'RET_ADDRESS_CALL286': 23595,
#  'RET_ADDRESS_CALL287': 23639,
#  'RET_ADDRESS_CALL288': 23681,
#  'RET_ADDRESS_CALL289': 23836,
#  'RET_ADDRESS_EQ29': 23931,
#  'screen.drawhorizontal$if_true1': 23938,
#  'RET_ADDRESS_CALL290': 23980,
#  'screen.drawhorizontal$if_false1': 23987,
#  'RET_ADDRESS_CALL291': 24015,
#  'screen.drawhorizontal$while_exp0': 24042,
#  'RET_ADDRESS_LT50': 24062,
#  'RET_ADDRESS_CALL292': 24097,
#  'screen.drawhorizontal$while_end0': 24126,
#  'RET_ADDRESS_CALL293': 24156,
#  'screen.drawhorizontal$if_end1': 24161,
#  'screen.drawsymetric': 24168,
#  'RET_ADDRESS_CALL294': 24241,
#  'RET_ADDRESS_CALL295': 24319,
#  'RET_ADDRESS_CALL296': 24398,
#  'RET_ADDRESS_CALL297': 24477,
#  'screen.drawcircle': 24488,
#  'LOOP_screen.drawcircle': 24490,
#  'RET_ADDRESS_LT51': 24512,
#  'RET_ADDRESS_GT39': 24529,
#  'RET_ADDRESS_LT52': 24549,
#  'RET_ADDRESS_GT40': 24571,
#  'screen.drawcircle$if_true0': 24583,
#  'RET_ADDRESS_CALL298': 24601,
#  'screen.drawcircle$if_false0': 24606,
#  'RET_ADDRESS_LT53': 24634,
#  'RET_ADDRESS_GT41': 24664,
#  'RET_ADDRESS_LT54': 24697,
#  'RET_ADDRESS_GT42': 24732,
#  'screen.drawcircle$if_true1': 24744,
#  'RET_ADDRESS_CALL299': 24762,
#  'screen.drawcircle$if_false1': 24767,
#  'RET_ADDRESS_CALL300': 24845,
#  'screen.drawcircle$while_exp0': 24850,
#  'RET_ADDRESS_GT43': 24868,
#  'RET_ADDRESS_LT55': 24892,
#  'screen.drawcircle$if_true2': 24899,
#  'RET_ADDRESS_CALL301': 24932,
#  'screen.drawcircle$if_false2': 24957,
#  'RET_ADDRESS_CALL302': 25002,
#  'screen.drawcircle$if_end2': 25047,
#  'RET_ADDRESS_CALL303': 25109,
#  'screen.drawcircle$while_end0': 25116,
#  'string.new': 25122,
#  'RET_ADDRESS_CALL304': 25140,
#  'RET_ADDRESS_LT56': 25160,
#  'string.new$if_true0': 25167,
#  'RET_ADDRESS_CALL305': 25185,
#  'string.new$if_false0': 25190,
#  'RET_ADDRESS_GT44': 25205,
#  'string.new$if_true1': 25212,
#  'RET_ADDRESS_CALL306': 25231,
#  'string.new$if_false1': 25237,
#  'string.dispose': 25269,
#  'RET_ADDRESS_GT45': 25296,
#  'string.dispose$if_true0': 25303,
#  'RET_ADDRESS_CALL307': 25322,
#  'string.dispose$if_false0': 25327,
#  'RET_ADDRESS_CALL308': 25345,
#  'string.length': 25356,
#  'string.charat': 25378,
#  'RET_ADDRESS_LT57': 25405,
#  'RET_ADDRESS_GT46': 25424,
#  'RET_ADDRESS_EQ30': 25448,
#  'string.charat$if_true0': 25460,
#  'RET_ADDRESS_CALL309': 25478,
#  'string.charat$if_false0': 25483,
#  'string.setcharat': 25516,
#  'RET_ADDRESS_LT58': 25543,
#  'RET_ADDRESS_GT47': 25562,
#  'RET_ADDRESS_EQ31': 25586,
#  'string.setcharat$if_true0': 25598,
#  'RET_ADDRESS_CALL310': 25616,
#  'string.setcharat$if_false0': 25621,
#  'string.appendchar': 25676,
#  'RET_ADDRESS_EQ32': 25707,
#  'string.appendchar$if_true0': 25714,
#  'RET_ADDRESS_CALL311': 25732,
#  'string.appendchar$if_false0': 25737,
#  'string.eraselastchar': 25818,
#  'RET_ADDRESS_EQ33': 25846,
#  'string.eraselastchar$if_true0': 25853,
#  'RET_ADDRESS_CALL312': 25871,
#  'string.eraselastchar$if_false0': 25876,
#  'string.intvalue': 25906,
#  'LOOP_string.intvalue': 25908,
#  'RET_ADDRESS_EQ34': 25943,
#  'string.intvalue$if_true0': 25950,
#  'string.intvalue$if_false0': 25956,
#  'RET_ADDRESS_EQ35': 26009,
#  'string.intvalue$if_true1': 26016,
#  'string.intvalue$if_false1': 26042,
#  'RET_ADDRESS_LT59': 26062,
#  'RET_ADDRESS_LT60': 26149,
#  'RET_ADDRESS_GT48': 26167,
#  'string.intvalue$if_true2': 26199,
#  'RET_ADDRESS_CALL313': 26224,
#  'string.intvalue$if_false2': 26265,
#  'string.intvalue$while_end0': 26267,
#  'string.intvalue$if_true3': 26283,
#  'string.intvalue$if_false3': 26300,
#  'string.setint': 26309,
#  'LOOP_string.setint': 26311,
#  'RET_ADDRESS_EQ36': 26345,
#  'string.setint$if_true0': 26352,
#  'RET_ADDRESS_CALL314': 26370,
#  'string.setint$if_false0': 26375,
#  'RET_ADDRESS_CALL315': 26393,
#  'RET_ADDRESS_LT61': 26415,
#  'string.setint$if_true1': 26422,
#  'string.setint$if_false1': 26454,
#  'string.setint$while_exp0': 26467,
#  'RET_ADDRESS_GT49': 26482,
#  'RET_ADDRESS_CALL316': 26515,
#  'RET_ADDRESS_CALL317': 26579,
#  'string.setint$while_end0': 26648,
#  'string.setint$if_true2': 26664,
#  'string.setint$if_false2': 26734,
#  'RET_ADDRESS_LT62': 26752,
#  'string.setint$if_true3': 26759,
#  'RET_ADDRESS_CALL318': 26777,
#  'string.setint$if_false3': 26782,
#  'RET_ADDRESS_EQ37': 26797,
#  'string.setint$if_true4': 26804,
#  'string.setint$if_false4': 26861,
#  'string.setint$while_exp1': 26872,
#  'RET_ADDRESS_LT63': 26891,
#  'string.setint$while_end1': 27021,
#  'RET_ADDRESS_CALL319': 27042,
#  'string.newline': 27053,
#  'string.backspace': 27061,
#  'string.doublequote': 27069,
#  'sys.init': 27077,
#  'RET_ADDRESS_CALL320': 27089,
#  'RET_ADDRESS_CALL321': 27106,
#  'RET_ADDRESS_CALL322': 27123,
#  'RET_ADDRESS_CALL323': 27140,
#  'RET_ADDRESS_CALL324': 27157,
#  'RET_ADDRESS_CALL325': 27174,
#  'RET_ADDRESS_CALL326': 27191,
#  'sys.halt': 27196,
#  'sys.halt$while_end0': 27214,
#  'RET_ADDRESS_LT64': 27234,
#  'sys.wait$if_true0': 27241,
#  'RET_ADDRESS_CALL327': 27257,
#  'sys.wait$if_false0': 27262,
#  'RET_ADDRESS_GT50': 27278,
#  'sys.wait$while_exp1': 27298,
#  'RET_ADDRESS_GT51': 27313,
#  'sys.wait$while_end1': 27345,
#  'sys.wait$while_end0': 27369,
#  'sys.error': 27375,
#  'RET_ADDRESS_CALL328': 27393,
#  'RET_ADDRESS_CALL329': 27411,
#  'RET_ADDRESS_CALL330': 27429,
#  'RET_ADDRESS_CALL331': 27447,
#  'RET_ADDRESS_CALL332': 27459,
#  'RET_ADDRESS_CALL333': 27483,
#  'RET_ADDRESS_CALL334': 27500}

# %%
inputFile = open('Pong.asm', 'r')


#process the data to remove // and space
files = input_preprcess(inputFile)

#Round 1 to replace Label Symbols
for line in files:
    if( line[0]=='('and line[len(line) - 1] == ')' ):
        index = files.index(line)
        files.remove(line)
        line = line.replace('(', "").replace(')',"")
        #add_symbol_to_symbolTable(symbols,line,index)
        symbols[line] = index

        
#Round 2 to replace variable symbols
result = []
for line in files:
    if line[0] == '@':
        result.append(parse_into_a_instruction(line))
    else:
        result.append(parse_into_c_instruction(line))
    

#Write result to the file
filename = 'Pong'
output = filename+'.hack'
outputFile = open(output,'w')

for line in result:
    outputFile.writelines(line + '\r\n')
outputFile.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-2dc5b7e38a5b> in <module>
#      21         result.append(parse_into_a_instruction(line))
#      22     else:
# ---> 23         result.append(parse_into_c_instruction(line))
#      24
#      25
#
# <ipython-input-33-dd29f15953cb> in parse_into_c_instruction(instruction)
#     114
#     115     result = '111'
# --> 116     result+=convert_comp_to_bin(comp)
#     117     result+=convert_dest_to_bin(dest)
#     118     result+=convert_jump_to_bin(jump)
#
# <ipython-input-33-dd29f15953cb> in convert_comp_to_bin(comp)
#      58         'D|M':'1010101',
#      59     }
# ---> 60     return compTable[comp]
#      61
#      62 def convert_dest_to_bin(dest):
#
# KeyError: '(ball.new)'
